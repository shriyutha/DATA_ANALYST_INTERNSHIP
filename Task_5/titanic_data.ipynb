# %% [markdown]
# # Titanic Dataset Analysis Report

# %% [markdown]
# ## Introduction:
#
# This project reports an exploratory data analysis performed on the Titanic dataset. The main objective was to clean the data, transform data types, engineer meaningful features, and prepare the dataset for analysis and modeling.

# %% [markdown]
# ## Dataset:
#
# The dataset contains information including ticket details, family relationships, and fare and many more outcomes.
#
# #### Columns and Data Types:
#
# PassengerId (int)
#
# Survived (categorical)
#
# Pclass (categorical)
#
# Sex (categorical)
#
# Age (float)
#
# SibSp (int)
#
# Parch (int)
#
# Fare (float)
#
# Ticket (object)
#
# Cabin (object)
#
# Embarked (categorical)
#
# LastName (object)
#
# FirstName (object)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('tested.csv', sep = ',')

# %%
data.shape
# Out:
# (418, 12)

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 360         1252         0       3                Sage, Master. William Henry
# 307         1199         0       3                  Aks, Master. Philip Frank
# 22           914         1       1       Flegenheim, Mrs. Alfred (Antoinette)
# 376         1268         1       3                          Kink, Miss. Maria
# 275         1167         1       2        Bryhl, Miss. Dagmar Jenny Ingeborg
# 202         1094         0       1                     Astor, Col. John Jacob
# 193         1085         0       2                          Lingane, Mr. John
# 199         1091         1       3    Rasmussen, Mrs. (Lena Jacobsen Solvang)
# 260         1152         0       3       de Messemaeker, Mr. Guillaume Joseph
# 8            900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
#
#         Sex    Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 360    male  14.50      8      2  CA. 2343   69.5500      NaN        S
# 307    male   0.83      0      1    392091    9.3500      NaN        S
# 22   female    NaN      0      0  PC 17598   31.6833      NaN        S
# 376  female  22.00      2      0    315152    8.6625      NaN        S
# 275  female  20.00      1      0    236853   26.0000      NaN        S
# 202    male  47.00      1      0  PC 17757  227.5250  C62 C64        C
# 193    male  61.00      0      0    235509   12.3500      NaN        Q
# 199  female    NaN      0      0     65305    8.1125      NaN        S
# 260    male  36.50      1      0    345572   17.4000      NaN        S
# 8    female  18.00      0      0      2657    7.2292      NaN        C

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.describe(include = 'object')
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[data[['Cabin', 'Age']].isna().all(axis = 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# 408                    Riordan, Miss. Johanna Hannah""  female  NaN      0
# 410                             Naughton, Miss. Hannah  female  NaN      0
# 413                                 Spector, Mr. Woolf    male  NaN      0
# 416                                Ware, Mr. Frederick    male  NaN      0
# 417                           Peter, Master. Michael J    male  NaN      1
#
#      Parch      Ticket     Fare Cabin Embarked
# 10       0      349220   7.8958   NaN        S
# 22       0    PC 17598  31.6833   NaN        S
# 29       0        2662  21.6792   NaN        C
# 33       2  W./C. 6607  23.4500   NaN        S
# 36       0      342712   8.0500   NaN        S
# ..     ...         ...      ...   ...      ...
# 408      0      334915   7.7208   NaN        Q
# 410      0      365237   7.7500   NaN        Q
# 413      0   A.5. 3236   8.0500   NaN        S
# 416      0      359309   8.0500   NaN        S
# 417      1        2668  22.3583   NaN        C
#
# [82 rows x 12 columns]

# %%
data['Ticket'].value_counts()[:10]
# Out:
# PC 17608              5
# CA. 2343              4
# 113503                4
# PC 17483              3
# 220845                3
# 347077                3
# SOTON/O.Q. 3101315    3
# C.A. 31029            3
# 16966                 3
# 230136                2
# Name: Ticket, dtype: int64

# %%
data[data['Ticket'] == 'PC 17608']
# Out:
#      PassengerId  Survived  Pclass  \
# 24           916         1       1
# 59           951         1       1
# 64           956         0       1
# 142         1034         0       1
# 375         1267         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 24   Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 59                       Chaudanson, Miss. Victorine  female  36.0      0
# 64                       Ryerson, Master. John Borie    male  13.0      2
# 142                       Ryerson, Mr. Arthur Larned    male  61.0      1
# 375                         Bowen, Miss. Grace Scott  female  45.0      0
#
#      Parch    Ticket     Fare            Cabin Embarked
# 24       3  PC 17608  262.375  B57 B59 B63 B66        C
# 59       0  PC 17608  262.375              B61        C
# 64       2  PC 17608  262.375  B57 B59 B63 B66        C
# 142      3  PC 17608  262.375  B57 B59 B63 B66        C
# 375      0  PC 17608  262.375              NaN        C

# %%
data[data['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 188         1080         1       3                 Sage, Miss. Ada  female
# 342         1234         0       3           Sage, Mr. John George    male
# 360         1252         0       3     Sage, Master. William Henry    male
# 365         1257         1       3  Sage, Mrs. John (Annie Bullen)  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 188   NaN      8      2  CA. 2343  69.55   NaN        S
# 342   NaN      1      9  CA. 2343  69.55   NaN        S
# 360  14.5      8      2  CA. 2343  69.55   NaN        S
# 365   NaN      1      9  CA. 2343  69.55   NaN        S

# %%
data['Fare'].value_counts()
# Out:
# 7.7500     21
# 26.0000    19
# 13.0000    17
# 8.0500     17
# 7.8958     11
#            ..
# 7.8208      1
# 8.5167      1
# 78.8500     1
# 52.0000     1
# 22.3583     1
# Name: Fare, Length: 169, dtype: int64

# %%
data[data['Age'] <= 1.0]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 117         1009         1       3          Sandstrom, Miss. Beatrice Irene
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 250         1142         1       2                    West, Miss. Barbara J
# 263         1155         1       3             Klasen, Miss. Gertrud Emilia
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 296         1188         1       2                    Laroche, Miss. Louise
# 307         1199         0       3                Aks, Master. Philip Frank
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 117  female  1.00      1      1             PP 9549  16.7000    G6        S
# 201    male  0.33      0      2              347080  14.4000   NaN        S
# 250  female  0.92      1      2          C.A. 34651  27.7500   NaN        S
# 263  female  1.00      1      1              350405  12.1833   NaN        S
# 281    male  0.75      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 296  female  1.00      1      2       SC/Paris 2123  41.5792   NaN        C
# 307    male  0.83      0      1              392091   9.3500   NaN        S
# 354  female  0.17      1      2           C.A. 2315  20.5750   NaN        S

# %%
data[(data['Age'] <= 3.0) & (data['Age'] > 1.0)]
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex  Age  \
# 89           981         0       2  Wells, Master. Ralph Lester    male  2.0
# 284         1176         1       3  Rosblom, Miss. Salli Helena  female  2.0
# 409         1301         1       3    Peacock, Miss. Treasteall  female  3.0
#
#      SibSp  Parch              Ticket     Fare Cabin Embarked
# 89       1      1               29103  23.0000   NaN        S
# 284      1      1              370129  20.2125   NaN        S
# 409      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S

# %%
data[(data['Age'] >= 60.0) & (data['Age'] <= 80.0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2            894         0       2
# 13           905         0       2
# 48           940         1       1
# 69           961         1       1
# 81           973         0       1
# 96           988         1       1
# 114         1006         1       1
# 142         1034         0       1
# 152         1044         0       3
# 179         1071         1       1
# 193         1085         0       2
# 213         1105         1       2
# 236         1128         0       1
# 305         1197         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 48     Bucknell, Mrs. William Robert (Emma Eliza Ward)  female  60.0      0
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 114             Straus, Mrs. Isidor (Rosalie Ida Blun)  female  63.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# 152                                 Storey, Mr. Thomas    male  60.5      0
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 193                                  Lingane, Mr. John    male  61.0      0
# 213       Howard, Mrs. Benjamin (Ellen Truelove Arman)  female  60.0      1
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
#
#      Parch    Ticket      Fare            Cabin Embarked
# 2        0    240276    9.6875              NaN        Q
# 13       0     24065   26.0000              NaN        S
# 48       0     11813   76.2917              D15        C
# 69       4     19950  263.0000      C23 C25 C27        S
# 81       0  PC 17483  221.7792          C55 C57        S
# 96       0     19877   78.8500              C46        S
# 114      0  PC 17483  221.7792          C55 C57        S
# 142      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 152      0      3701       NaN              NaN        S
# 179      2  PC 17756   83.1583              E45        C
# 193      0    235509   12.3500              NaN        Q
# 213      0     24065   26.0000              NaN        S
# 236      0    110813   75.2500              D37        C
# 305      1    112901   26.5500              B26        S

# %% [markdown]
# ## Data Cleaning:
#
# #### Handling Missing Values:
#
#     Age: Missing values were filled using the median age grouped by passenger(Pclass).
#
#     Cabin: Missing values were replaced with the label 'No Cabin'.
#
# #### Data Type Standardization:
#
#     Columns were converted from object or int to category using .astype('category') to improve memory efficiency.
#     Split Full Name into 2 seperate columns and removed Prefix for better analysis.
#     Droped NA's

# %%
data['Survived'] = data['Survived'].astype('category')
data['Pclass']   = data['Pclass'].astype('category')
data['Sex']      = data['Sex'].astype('category')
data['Embarked'] = data['Embarked'].astype('category')

# %%
data['Cabin'] = data['Cabin'].fillna('No_Cabin')

# %%
median_age = round(data.loc[data['Pclass'] == 3, 'Age'].median(), 1)
median_age
# Out:
# 24.0

# %%
data.loc[(data['Age'].isna()) & (data['Pclass'] == 3), 'Age'] = median_age

# %%
data = data.dropna()

# %%
data
# Out:
#      PassengerId Survived Pclass  \
# 0            892        0      3
# 1            893        1      3
# 2            894        0      2
# 3            895        0      3
# 4            896        1      3
# ..           ...      ...    ...
# 413         1305        0      3
# 414         1306        1      1
# 415         1307        0      3
# 416         1308        0      3
# 417         1309        0      3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male  24.0      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male  24.0      0      0
# 417                      Peter, Master. Michael J    male  24.0      1      1
#
#                  Ticket      Fare     Cabin Embarked
# 0                330911    7.8292  No_Cabin        Q
# 1                363272    7.0000  No_Cabin        S
# 2                240276    9.6875  No_Cabin        Q
# 3                315154    8.6625  No_Cabin        S
# 4               3101298   12.2875  No_Cabin        S
# ..                  ...       ...       ...      ...
# 413           A.5. 3236    8.0500  No_Cabin        S
# 414            PC 17758  108.9000      C105        C
# 415  SOTON/O.Q. 3101262    7.2500  No_Cabin        S
# 416              359309    8.0500  No_Cabin        S
# 417                2668   22.3583  No_Cabin        C
#
# [403 rows x 12 columns]

# %%
data[['Last_Name', 'First_Name']] = data['Name'].str.split(',', expand = True)
data['First_Name'] = data['First_Name'].str.split('.').str[1].str.strip()

data.drop(columns = 'Name', inplace = True)

# %% [markdown]
# ## Feature Engineering:
#
# #### Family Based Features:
#
#     Created new column 'Family_Members' by using SibSp and Parch: Family_Members = SibSp + Parch + 1
#
# #### Age and Fare Segmentation:
#
#     Passengers were categorized into meaningful life stages using conditional logic and passengers were categorized into fare categories.

# %%
def Age(data):
    if data <= 1:
        return 'Infant'
    elif 1 < data <= 3:
        return 'Toddler'
    elif 3 < data <= 13:
        return 'Child'
    elif 13 < data <= 18:
        return 'Teen'
    elif 60 <= data <= 80:
        return 'Senior'
    else:
        return 'Adult'

data['Age_Category'] = data['Age'].apply(Age)

# %%
data['Price_Category'] = pd.cut(data['Fare'], bins = (0, 20, 60, 100, 200, data['Fare'].max()), labels = ['Very_Low', 'Low', 'Medium', 'High', 'Luxury'])

# %%
data['Family_Members'] = data['SibSp'] + data['Parch'] + 1

# %%
data
# Out:
#      PassengerId Survived Pclass     Sex   Age  SibSp  Parch  \
# 0            892        0      3    male  34.5      0      0
# 1            893        1      3  female  47.0      1      0
# 2            894        0      2    male  62.0      0      0
# 3            895        0      3    male  27.0      0      0
# 4            896        1      3  female  22.0      1      1
# ..           ...      ...    ...     ...   ...    ...    ...
# 413         1305        0      3    male  24.0      0      0
# 414         1306        1      1  female  39.0      0      0
# 415         1307        0      3    male  38.5      0      0
# 416         1308        0      3    male  24.0      0      0
# 417         1309        0      3    male  24.0      1      1
#
#                  Ticket      Fare     Cabin Embarked      Last_Name  \
# 0                330911    7.8292  No_Cabin        Q          Kelly
# 1                363272    7.0000  No_Cabin        S         Wilkes
# 2                240276    9.6875  No_Cabin        Q          Myles
# 3                315154    8.6625  No_Cabin        S           Wirz
# 4               3101298   12.2875  No_Cabin        S       Hirvonen
# ..                  ...       ...       ...      ...            ...
# 413           A.5. 3236    8.0500  No_Cabin        S        Spector
# 414            PC 17758  108.9000      C105        C  Oliva y Ocana
# 415  SOTON/O.Q. 3101262    7.2500  No_Cabin        S        Saether
# 416              359309    8.0500  No_Cabin        S           Ware
# 417                2668   22.3583  No_Cabin        C          Peter
#
#                         First_Name Age_Category Price_Category  Family_Members
# 0                            James        Adult       Very_Low               1
# 1              James (Ellen Needs)        Adult       Very_Low               2
# 2                   Thomas Francis       Senior       Very_Low               1
# 3                           Albert        Adult       Very_Low               1
# 4    Alexander (Helga E Lindqvist)        Adult       Very_Low               3
# ..                             ...          ...            ...             ...
# 413                          Woolf        Adult       Very_Low               1
# 414                        Fermina        Adult           High               1
# 415                Simon Sivertsen        Adult       Very_Low               1
# 416                      Frederick        Adult       Very_Low               1
# 417                      Michael J        Adult            Low               3
#
# [403 rows x 16 columns]

# %%
data.to_csv('Titanic_data.csv', index = False)

# %% [markdown]
# ## Key Insights:
#
# * Gender had a strong impact on survival
# * Passenger class (Pclass) strongly influenced survival
# * Infants and children had higher survival rates compared to adults.
# * Senior passengers had lower survival rates.
# * Family size mattered more than traveling alone
# * Cabin availability indicated survival advantage

# %% [markdown]
# ## Conclusion:
#
# The data cleaning, data type conversion, and feature engineering, the Titanic dataset was transformed into a structured and analysis ready format to improved data quality, interpretability, and suitability for the exploratory analysis and machine learning models.

# %% [markdown]
# ## Tools Used:
#
# Python
#
# Pandas
#
# NumPy
#
# Jupyter Notebook
